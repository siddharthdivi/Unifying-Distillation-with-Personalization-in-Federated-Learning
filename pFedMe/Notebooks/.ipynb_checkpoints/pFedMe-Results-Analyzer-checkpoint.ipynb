# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
# Helper function to help read the h5 files.
def simple_read_data(fileName):
    print(fileName)
    hf = h5py.File('{}.h5'.format(fileName), 'r')
    
    # We'll return a dictionary object. 
    results = {}
    
    results['rs_glob_acc'] = np.array(hf.get('rs_glob_acc')[:])
    results['rs_train_acc'] = np.array(hf.get('rs_train_acc')[:])
    results['rs_train_loss'] = np.array(hf.get('rs_train_loss')[:])
    
    # 3D array: Read as [number of times, number of epochs, number of users].
    results['perUserAccs'] = np.array(hf.get('perUserAccs'))
    
    return results

# %% [markdown]
# ### Datasplit-1

# %%
# Define the global directory path.
directoryPath = '/home/adgdri/pFedMe/results/Datasplit-1/'

# %% [markdown]
# #### Num Epochs: 50

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_50',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_50',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_50',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_50',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_50',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]
    plt.plot(ob['rs_train_loss'])
    
plt.title('Train loss curves.')
plt.legend(['R0','R1','R2','R3','R4',])
plt.show()
# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_50
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_50
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_50
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_50
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_50
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6483, 0.6005, 0.6593, 0.5942, 0.5747]
#
#  Average accuracy across all the different runs : 0.615400.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6776]
#  [0.5676]
#  [0.6262]
#  [0.6104]
#  [0.6062]
#  [0.5494]
#  [0.5368]
#  [0.5816]
#  [0.6624]
#  [0.7358]].
#
#  Average accuracy averaged over different runs:
#  0.6154000000000001.

# %% [markdown]
# #### Num Epochs: 100

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_100',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_100',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_100',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_100',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_100',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]
    plt.plot(ob['rs_train_loss'])
    
plt.title('Train loss curves.')
plt.legend(['R0','R1','R2','R3','R4',])
plt.show()
# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_100
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_100
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_100
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_100
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_100
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6866, 0.6257, 0.6894, 0.6164, 0.5876]
#
#  Average accuracy across all the different runs : 0.641140.
#
#  Average per user accuracy averaged over different runs:
#  [[0.699 ]
#  [0.597 ]
#  [0.6408]
#  [0.646 ]
#  [0.6342]
#  [0.5772]
#  [0.552 ]
#  [0.6004]
#  [0.6958]
#  [0.769 ]].
#
#  Average accuracy averaged over different runs:
#  0.64114.

# %% [markdown]
# #### Num Epochs: 150

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_150',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_150',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_150',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_150',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_150',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]
    plt.plot(ob['rs_train_loss'])
    
plt.title('Train loss curves.')
plt.legend(['R0','R1','R2','R3','R4',])
plt.show()
# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_150
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_150
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_150
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_150
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_150
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7028, 0.6377, 0.6966, 0.6193, 0.5925]
#
#  Average accuracy across all the different runs : 0.649780.
#
#  Average per user accuracy averaged over different runs:
#  [[0.7022]
#  [0.606 ]
#  [0.656 ]
#  [0.6482]
#  [0.646 ]
#  [0.5894]
#  [0.5552]
#  [0.6084]
#  [0.7054]
#  [0.781 ]].
#
#  Average accuracy averaged over different runs:
#  0.64978.

# %% [markdown]
# #### Num Epochs: 200

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_200',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_200',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_200',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_200',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_200',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]
    plt.plot(ob['rs_train_loss'])
    
plt.title('Train loss curves.')
plt.legend(['R0','R1','R2','R3','R4',])
plt.show()
# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_200
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_200
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_200
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_200
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_200
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7018, 0.6363, 0.6962, 0.6092, 0.5882]
#
#  Average accuracy across all the different runs : 0.646340.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6976]
#  [0.5964]
#  [0.648 ]
#  [0.6504]
#  [0.6454]
#  [0.5834]
#  [0.5536]
#  [0.605 ]
#  [0.7044]
#  [0.7792]].
#
#  Average accuracy averaged over different runs:
#  0.64634.

# %% [markdown]
# #### Num Epochs: 250

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_250',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_250',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_250',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_250',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_250',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]
    plt.plot(ob['rs_train_loss'])
    
plt.title('Train loss curves.')
plt.legend(['R0','R1','R2','R3','R4',])
plt.show()
# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_250
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_250
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_250
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_250
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_250
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6969, 0.6263, 0.6937, 0.604, 0.5864]
#
#  Average accuracy across all the different runs : 0.641460.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6972]
#  [0.5864]
#  [0.6458]
#  [0.6398]
#  [0.646 ]
#  [0.5722]
#  [0.543 ]
#  [0.6048]
#  [0.6994]
#  [0.78  ]].
#
#  Average accuracy averaged over different runs:
#  0.64146.

# %% [markdown]
# #### Num Epochs: 300

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_300',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_300',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_300',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_300',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_300',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]
    plt.plot(ob['rs_train_loss'])
    
plt.title('Train loss curves.')
plt.legend(['R0','R1','R2','R3','R4',])
plt.show()
# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_300
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_300
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_300
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_300
# /home/adgdri/pFedMe/results/Datasplit-1/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_300
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6977, 0.6306, 0.6886, 0.6001, 0.5872]
#
#  Average accuracy across all the different runs : 0.640840.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6974]
#  [0.5856]
#  [0.6424]
#  [0.6364]
#  [0.643 ]
#  [0.5722]
#  [0.5492]
#  [0.6102]
#  [0.6926]
#  [0.7794]].
#
#  Average accuracy averaged over different runs:
#  0.64084.

# %% [markdown]
# ### Datasplit-2

# %%
# Define the global directory path.
directoryPath = '/home/adgdri/pFedMe/results/'

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.005_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.005_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7031]
#
#  Average accuracy across all the different runs : 0.703100.
#
#  Average per user accuracy averaged over different runs:
#  [[0.654]
#  [0.755]
#  [0.556]
#  [0.869]
#  [0.663]
#  [0.654]
#  [0.608]
#  [0.715]
#  [0.75 ]
#  [0.807]].
#
#  Average accuracy averaged over different runs:
#  0.7031000000000001.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.005_avg_roundNum_0_globalIters_1200_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.005_avg_roundNum_0_globalIters_1200_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6994]
#
#  Average accuracy across all the different runs : 0.699400.
#
#  Average per user accuracy averaged over different runs:
#  [[0.641]
#  [0.759]
#  [0.549]
#  [0.858]
#  [0.658]
#  [0.661]
#  [0.618]
#  [0.725]
#  [0.74 ]
#  [0.785]].
#
#  Average accuracy averaged over different runs:
#  0.6994.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.71]
#
#  Average accuracy across all the different runs : 0.710000.
#
#  Average per user accuracy averaged over different runs:
#  [[0.682]
#  [0.766]
#  [0.558]
#  [0.886]
#  [0.669]
#  [0.673]
#  [0.588]
#  [0.742]
#  [0.749]
#  [0.787]].
#
#  Average accuracy averaged over different runs:
#  0.71.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_1200_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_1200_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7071]
#
#  Average accuracy across all the different runs : 0.707100.
#
#  Average per user accuracy averaged over different runs:
#  [[0.692]
#  [0.762]
#  [0.546]
#  [0.889]
#  [0.653]
#  [0.66 ]
#  [0.593]
#  [0.734]
#  [0.75 ]
#  [0.792]].
#
#  Average accuracy averaged over different runs:
#  0.7071.

# %%
# Hyper-params for CIFAR-10 DS-1 fixed.
# personal learning rate: 0.001 
# global epochs: 800

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7344]
#
#  Average accuracy across all the different runs : 0.734400.
#
#  Average per user accuracy averaged over different runs:
#  [[0.726]
#  [0.785]
#  [0.585]
#  [0.904]
#  [0.67 ]
#  [0.674]
#  [0.621]
#  [0.776]
#  [0.787]
#  [0.816]].
#
#  Average accuracy averaged over different runs:
#  0.7343999999999999.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_1200_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_1200_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7319]
#
#  Average accuracy across all the different runs : 0.731900.
#
#  Average per user accuracy averaged over different runs:
#  [[0.726]
#  [0.779]
#  [0.577]
#  [0.904]
#  [0.666]
#  [0.672]
#  [0.619]
#  [0.781]
#  [0.782]
#  [0.813]].
#
#  Average accuracy averaged over different runs:
#  0.7319.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.672]
#
#  Average accuracy across all the different runs : 0.672000.
#
#  Average per user accuracy averaged over different runs:
#  [[0.624]
#  [0.708]
#  [0.523]
#  [0.85 ]
#  [0.609]
#  [0.603]
#  [0.569]
#  [0.707]
#  [0.724]
#  [0.803]].
#
#  Average accuracy averaged over different runs:
#  0.6719999999999999.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_1000_dataSplit_2',
#     'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_1000_dataSplit_2',
#     'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_1000_dataSplit_2',
#     'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_1000_dataSplit_2',
#    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_1000_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5494351694491653]
#
#  Average accuracy across all the different runs : 0.549435.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5707]
#  [0.5222]
#  [0.5476]
#  [0.5861]
#  [0.5606]
#  [0.5787]
#  [0.5019]
#  [0.5688]
#  [0.5228]
#  [0.5424]].
#
#  Average accuracy averaged over different runs:
#  0.55018.

# %%
# DS2 params
# Global Iters: 1000
# Personal learning rate: 0.0025

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_1000_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5927221833449965]
#
#  Average accuracy across all the different runs : 0.592722.
#
#  Average per user accuracy averaged over different runs:
#  [[0.601 ]
#  [0.5599]
#  [0.5979]
#  [0.6445]
#  [0.602 ]
#  [0.6202]
#  [0.5474]
#  [0.6039]
#  [0.5644]
#  [0.6008]].
#
#  Average accuracy averaged over different runs:
#  0.5942000000000001.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_1200_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_1200_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5946216135159452]
#
#  Average accuracy across all the different runs : 0.594622.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6117]
#  [0.5626]
#  [0.5885]
#  [0.6177]
#  [0.6114]
#  [0.6263]
#  [0.5518]
#  [0.6078]
#  [0.5792]
#  [0.5836]].
#
#  Average accuracy averaged over different runs:
#  0.59406.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.005_avg_roundNum_0_globalIters_1000_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.005_avg_roundNum_0_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5825252424272718]
#
#  Average accuracy across all the different runs : 0.582525.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6039]
#  [0.5707]
#  [0.5916]
#  [0.6035]
#  [0.5887]
#  [0.6196]
#  [0.5421]
#  [0.5675]
#  [0.5564]
#  [0.5743]].
#
#  Average accuracy averaged over different runs:
#  0.58183.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.005_avg_roundNum_0_globalIters_1200_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.005_avg_roundNum_0_globalIters_1200_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5765270418874338]
#
#  Average accuracy across all the different runs : 0.576527.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5834]
#  [0.5532]
#  [0.577 ]
#  [0.594 ]
#  [0.5887]
#  [0.6122]
#  [0.5414]
#  [0.5701]
#  [0.5604]
#  [0.5743]].
#
#  Average accuracy averaged over different runs:
#  0.5754699999999999.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_0_globalIters_1000_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_0_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5639308207537739]
#
#  Average accuracy across all the different runs : 0.563931.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5678]
#  [0.5559]
#  [0.5529]
#  [0.5956]
#  [0.5692]
#  [0.5954]
#  [0.519 ]
#  [0.5922]
#  [0.5515]
#  [0.5504]].
#
#  Average accuracy averaged over different runs:
#  0.56499.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_0_globalIters_1200_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_0_globalIters_1200_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.557332800159952]
#
#  Average accuracy across all the different runs : 0.557333.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5571]
#  [0.537 ]
#  [0.5393]
#  [0.5735]
#  [0.5715]
#  [0.5914]
#  [0.5168]
#  [0.5922]
#  [0.5416]
#  [0.5531]].
#
#  Average accuracy averaged over different runs:
#  0.5573499999999999.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_1800_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_1800_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6001199640107968]
#
#  Average accuracy across all the different runs : 0.600120.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6244]
#  [0.5693]
#  [0.5843]
#  [0.6382]
#  [0.6114]
#  [0.6383]
#  [0.5645]
#  [0.5831]
#  [0.5881]
#  [0.5875]].
#
#  Average accuracy averaged over different runs:
#  0.5989099999999999.

# %% [markdown]
# ### Datasplit-3

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7717827833071416]
#
#  Average accuracy across all the different runs : 0.771783.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9202]
#  [0.7415]
#  [0.6308]
#  [0.8122]
#  [0.7551]
#  [0.7783]
#  [0.87  ]
#  [0.8517]
#  [0.7146]
#  [0.7474]].
#
#  Average accuracy averaged over different runs:
#  0.78218.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7838309760782259]
#
#  Average accuracy across all the different runs : 0.783831.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9252]
#  [0.7718]
#  [0.6424]
#  [0.7991]
#  [0.7698]
#  [0.7831]
#  [0.8863]
#  [0.8553]
#  [0.7024]
#  [0.768 ]].
#
#  Average accuracy averaged over different runs:
#  0.7903399999999999.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.005_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.005_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.787323205866946]
#
#  Average accuracy across all the different runs : 0.787323.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9202]
#  [0.7807]
#  [0.6507]
#  [0.8297]
#  [0.7808]
#  [0.7831]
#  [0.8827]
#  [0.8734]
#  [0.6927]
#  [0.7646]].
#
#  Average accuracy averaged over different runs:
#  0.79586.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7784180199057098]
#
#  Average accuracy across all the different runs : 0.778418.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9352]
#  [0.795 ]
#  [0.649 ]
#  [0.8035]
#  [0.7643]
#  [0.7904]
#  [0.8736]
#  [0.8644]
#  [0.6805]
#  [0.7392]].
#
#  Average accuracy averaged over different runs:
#  0.7895100000000002.

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_800_dataSplit_3
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-d4b4fe21d937> in <module>
#      11
#      12 for fileName in fileNames:
# ---> 13     ob = simple_read_data(directoryPath + fileName)
#      14     avgPersAcc.append( ob['rs_glob_acc'][-1] )
#      15     # Take the per user accuracy from the last epoch.
#
# <ipython-input-3-03dee00efe01> in simple_read_data(fileName)
#       2 def simple_read_data(fileName):
#       3     print(fileName)
# ----> 4     hf = h5py.File('{}.h5'.format(fileName), 'r')
#       5
#       6     # We'll return a dictionary object.
#
# ~/miniconda3/envs/torchenv/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     310             with phil:
#     311                 fapl = make_fapl(driver, libver, **kwds)
# --> 312                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     313
#     314                 if swmr_support:
#
# ~/miniconda3/envs/torchenv/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     140         if swmr and swmr_support:
#     141             flags |= h5f.ACC_SWMR_READ
# --> 142         fid = h5f.open(name, flags, fapl=fapl)
#     143     elif mode == 'r+':
#     144         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_800_dataSplit_3.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %% [markdown]
# #### Num Epochs: 25

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_25_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_25_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_25_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_25_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_25_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_25_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.15375387383784864, 0.16205138458462462, 0.15346930613877224, 0.14385684294711587, 0.1375587323802859]
#
#  Average accuracy across all the different runs : 0.150138.
#
#  Average per user accuracy averaged over different runs:
#  [[0.1717]
#  [0.124 ]
#  [0.1241]
#  [0.1603]
#  [0.1174]
#  [0.1142]
#  [0.2111]
#  [0.1474]
#  [0.1608]
#  [0.1826]].
#
#  Average accuracy averaged over different runs:
#  0.15136.

# %% [markdown]
# #### Num Epochs: 50

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_50_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_50_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_50_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_50_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_50_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_50_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.15255423372988103, 0.2210336898930321, 0.21105778844231154, 0.1858442467259822, 0.20703788863340997]
#
#  Average accuracy across all the different runs : 0.195506.
#
#  Average per user accuracy averaged over different runs:
#  [[0.2099]
#  [0.172 ]
#  [0.1541]
#  [0.2043]
#  [0.2043]
#  [0.1629]
#  [0.2826]
#  [0.2189]
#  [0.1672]
#  [0.223 ]].
#
#  Average accuracy averaged over different runs:
#  0.19992000000000001.

# %% [markdown]
# #### Num Epochs: 100

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_100_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_100_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_100_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_100_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_100_dataSplit_2',
]

# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_100_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_100_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_100_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_100_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_100_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.3962811156653004, 0.4239728081575527, 0.38962207558488304, 0.3580925722283315, 0.35379386184144757]
#
#  Average accuracy across all the different runs : 0.384352.
#
#  Average per user accuracy averaged over different runs:
#  [[0.3981]
#  [0.3939]
#  [0.3453]
#  [0.4064]
#  [0.3961]
#  [0.4061]
#  [0.4036]
#  [0.3576]
#  [0.4036]
#  [0.3508]].
#
#  Average accuracy averaged over different runs:
#  0.38615.

# %% [markdown]
# #### Num Epochs: 200

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_200_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_200_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_200_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_200_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_200_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_200_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.455963211036689, 0.47515745276417076, 0.46010797840431916, 0.4322703189043287, 0.4221733479956013]
#
#  Average accuracy across all the different runs : 0.449134.
#
#  Average per user accuracy averaged over different runs:
#  [[0.4633]
#  [0.4539]
#  [0.4249]
#  [0.4756]
#  [0.4584]
#  [0.4642]
#  [0.4536]
#  [0.4435]
#  [0.447 ]
#  [0.4214]].
#
#  Average accuracy averaged over different runs:
#  0.4505800000000001.

# %% [markdown]
# #### Num Epochs: 300

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_300_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_300_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_300_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_300_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_300_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_300_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_300_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_300_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_300_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_300_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.49545136459062283, 0.5149455163450964, 0.49300139972005597, 0.47665700289913027, 0.4695591322603219]
#
#  Average accuracy across all the different runs : 0.489923.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5016]
#  [0.4907]
#  [0.4652]
#  [0.5185]
#  [0.4887]
#  [0.5002]
#  [0.4888]
#  [0.4999]
#  [0.4905]
#  [0.468 ]].
#
#  Average accuracy averaged over different runs:
#  0.49121.

# %% [markdown]
# #### Num Epochs: 400

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_400_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_400_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_400_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_400_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_400_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_400_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_400_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_400_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_400_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_400_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5185444366689993, 0.5402379286214136, 0.5112977404519096, 0.4980505848245526, 0.48805358392482256]
#
#  Average accuracy across all the different runs : 0.511237.
#
#  Average per user accuracy averaged over different runs:
#  [[0.523 ]
#  [0.5106]
#  [0.4887]
#  [0.5382]
#  [0.5112]
#  [0.5234]
#  [0.5116]
#  [0.5224]
#  [0.5069]
#  [0.4866]].
#
#  Average accuracy averaged over different runs:
#  0.51226.

# %% [markdown]
# #### Num Epochs: 500

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_500_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_500_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_500_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_500_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_500_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_500_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_500_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_500_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_500_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_500_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5345396381085674, 0.5598320503848845, 0.5302939412117577, 0.5148455463360991, 0.5089473158052584]
#
#  Average accuracy across all the different runs : 0.529692.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5446]
#  [0.5203]
#  [0.5083]
#  [0.5556]
#  [0.5297]
#  [0.5425]
#  [0.5296]
#  [0.5375]
#  [0.5271]
#  [0.5105]].
#
#  Average accuracy averaged over different runs:
#  0.53057.

# %% [markdown]
# #### Num Epochs: 600

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_600_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_600_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_600_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_600_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_600_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_600_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_600_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_600_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_600_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_600_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5453363990802759, 0.570628811356593, 0.5429914017196561, 0.5276417074877536, 0.5226432070378886]
#
#  Average accuracy across all the different runs : 0.541848.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5612]
#  [0.5263]
#  [0.521 ]
#  [0.5576]
#  [0.5369]
#  [0.5629]
#  [0.5377]
#  [0.5436]
#  [0.5446]
#  [0.5274]].
#
#  Average accuracy averaged over different runs:
#  0.54192.

# %% [markdown]
# #### Num Epochs: 800

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_800_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_800_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_800_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_800_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_800_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_800_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5630310906727981, 0.5916225132460262, 0.5585882823435313, 0.548335499350195, 0.5429371188643407]
#
#  Average accuracy across all the different runs : 0.560903.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5789]
#  [0.5439]
#  [0.5373]
#  [0.5701]
#  [0.5576]
#  [0.5779]
#  [0.5564]
#  [0.5671]
#  [0.566 ]
#  [0.5504]].
#
#  Average accuracy averaged over different runs:
#  0.56056.

# %% [markdown]
# #### Num Epochs: 1000

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_1000_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_1000_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_1000_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_1000_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_1000_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_1000_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_1000_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_1000_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_1000_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5813256023193042, 0.6083175047485754, 0.5721855628874225, 0.566630010996701, 0.5598320503848845]
#
#  Average accuracy across all the different runs : 0.577658.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5951]
#  [0.5598]
#  [0.5524]
#  [0.5886]
#  [0.5794]
#  [0.5965]
#  [0.5737]
#  [0.5831]
#  [0.5782]
#  [0.5644]].
#
#  Average accuracy averaged over different runs:
#  0.5771200000000001.

# %% [markdown]
# #### Num Epochs: 1200

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_1200_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_1200_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_1200_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_1200_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_1200_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_1200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_1200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_1200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_1200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_1200_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5884234729581126, 0.6231130660801759, 0.5843831233753249, 0.5752274317704689, 0.5711286614015795]
#
#  Average accuracy across all the different runs : 0.588455.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6054]
#  [0.5615]
#  [0.5698]
#  [0.592 ]
#  [0.5924]
#  [0.6092]
#  [0.584 ]
#  [0.5952]
#  [0.5882]
#  [0.5773]].
#
#  Average accuracy averaged over different runs:
#  0.5875.

# %% [markdown]
# #### Num Epochs: 1500

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_1500_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_1500_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_1500_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_1500_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_1500_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_1500_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_1500_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_1500_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_1500_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_1500_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5974207737678696, 0.6320103968809357, 0.5921815636872626, 0.5810256922923123, 0.584924522643207]
#
#  Average accuracy across all the different runs : 0.597513.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6144]
#  [0.5685]
#  [0.5784]
#  [0.6031]
#  [0.5991]
#  [0.6209]
#  [0.5897]
#  [0.6013]
#  [0.6   ]
#  [0.5838]].
#
#  Average accuracy averaged over different runs:
#  0.5959199999999999.

# %% [markdown]
# ### Datasplit-2

# %%
# Define the global directory path.
directoryPath = '/home/adgdri/pFedMe/results/'

# %% [markdown]
# #### Num Epochs: 25

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_25_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_25_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_25_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_25_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_25_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_25_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.32100108813928185, 0.26811956413076077, 0.2437268819354194, 0.24020391843262695, 0.29518192722910835]
#
#  Average accuracy across all the different runs : 0.273647.
#
#  Average per user accuracy averaged over different runs:
#  [[0.2831]
#  [0.2717]
#  [0.2529]
#  [0.2345]
#  [0.2822]
#  [0.2884]
#  [0.2538]
#  [0.2775]
#  [0.3229]
#  [0.3125]].

# %% [markdown]
# #### Num Epochs: 50

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_50_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_50_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_50_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_50_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_50_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_50_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.30359085963003263, 0.26552034389683093, 0.24582625212436268, 0.23940423830467814, 0.29518192722910835]
#
#  Average accuracy across all the different runs : 0.269905.
#
#  Average per user accuracy averaged over different runs:
#  [[0.28260379]
#  [0.26907898]
#  [0.24615437]
#  [0.21783808]
#  [0.28177729]
#  [0.28892454]
#  [0.25144363]
#  [0.27676443]
#  [0.32187224]
#  [0.31221244]].

# %% [markdown]
# ### Datasplit-3

# %% [markdown]
# #### Num Epochs: 50

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_50_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_50_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_50_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_50_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_50_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_50_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_50_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_50_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_50_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_50_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5133577789418544, 0.5217391304347826, 0.5210406844770386, 0.5219137419242186, 0.5233106338397067]
#
#  Average accuracy across all the different runs : 0.520272.
#
#  Average per user accuracy averaged over different runs:
#  [[0.7646]
#  [0.5462]
#  [0.4798]
#  [0.5109]
#  [0.7282]
#  [0.5557]
#  [0.4816]
#  [0.5418]
#  [0.3205]
#  [0.4365]].

# %% [markdown]
# #### Num Epochs: 100

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_100_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_100_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_100_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_100_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_100_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:, -1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_0_globalIters_100_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_1_globalIters_100_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_2_globalIters_100_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_3_globalIters_100_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.01_avg_roundNum_4_globalIters_100_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5119608870263663, 0.5165007857517024, 0.5177230661777545, 0.5243583027763227, 0.5213899074559106]
#
#  Average accuracy across all the different runs : 0.518387.
#
#  Average per user accuracy averaged over different runs:
#  [[0.7646]
#  [0.5462]
#  [0.4798]
#  [0.4734]
#  [0.7282]
#  [0.5557]
#  [0.4816]
#  [0.5418]
#  [0.3244]
#  [0.4339]].

# %% [markdown]
# ### Datasplit - 2

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_1000_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_1_globalIters_1000_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_2_globalIters_1000_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_3_globalIters_1000_dataSplit_2',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_4_globalIters_1000_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_0_globalIters_1000_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_1_globalIters_1000_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_2_globalIters_1000_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_3_globalIters_1000_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0025_avg_roundNum_4_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5931220633809857, 0.6175147455763271, 0.5991801639672065, 0.5862241327601719, 0.5679296211136659]
#
#  Average accuracy across all the different runs : 0.592794.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6166]
#  [0.5725]
#  [0.5729]
#  [0.5892]
#  [0.595 ]
#  [0.6062]
#  [0.5855]
#  [0.6023]
#  [0.5956]
#  [0.5833]].
#
#  Average accuracy averaged over different runs:
#  0.59191.

# %% [markdown]
# ### Datasplit - 1

# %%
directoryPath = '/home/adgdri/pFedMe/results/'

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_800_dataSplit_1',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_800_dataSplit_1',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_800_dataSplit_1',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_800_dataSplit_1',
    'Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_800_dataSplit_1',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_0_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_1_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_2_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_3_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.001_avg_roundNum_4_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7344, 0.675, 0.7351, 0.6594, 0.6437]
#
#  Average accuracy across all the different runs : 0.689520.
#
#  Average per user accuracy averaged over different runs:
#  [[0.7428]
#  [0.6412]
#  [0.6956]
#  [0.6936]
#  [0.672 ]
#  [0.6206]
#  [0.599 ]
#  [0.6584]
#  [0.7546]
#  [0.8174]].
#
#  Average accuracy averaged over different runs:
#  0.68952.

# %% [markdown]
# ### Datasplit-2

# %%
fileNames = [
    'Mnist_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_0_globalIters_800_dataSplit_2',
    'Mnist_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_1_globalIters_800_dataSplit_2',
    'Mnist_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_2_globalIters_800_dataSplit_2',
    'Mnist_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_3_globalIters_800_dataSplit_2',
    'Mnist_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_4_globalIters_800_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Mnist_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_0_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Mnist_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_1_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Mnist_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_2_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Mnist_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_3_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Mnist_pFedMe_p_0.01_1.0_15_10u_128b_20_5_0.0075_avg_roundNum_4_globalIters_800_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.8736024579670564, 0.8736240293540405, 0.8668601177775881, 0.8685782556750299, 0.868236900494965]
#
#  Average accuracy across all the different runs : 0.870180.
#
#  Average per user accuracy averaged over different runs:
#  [[0.8821]
#  [0.8608]
#  [0.8536]
#  [0.867 ]
#  [0.8739]
#  [0.8531]
#  [0.8795]
#  [0.8774]
#  [0.8787]
#  [0.8864]].
#
#  Average accuracy averaged over different runs:
#  0.8712500000000001.

# %% [markdown]
# ### CIFAR-10 pFedMe paper check

# %%
fileNames = [
    'Cifar10_pFedMe_p_0.01_2.0_30_10u_20b_20_5_0.05_avg_roundNum_0_globalIters_800_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_2.0_30_10u_20b_20_5_0.05_avg_roundNum_1_globalIters_800_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_2.0_30_10u_20b_20_5_0.05_avg_roundNum_2_globalIters_800_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_2.0_30_10u_20b_20_5_0.05_avg_roundNum_3_globalIters_800_dataSplit_3',
    'Cifar10_pFedMe_p_0.01_2.0_30_10u_20b_20_5_0.05_avg_roundNum_4_globalIters_800_dataSplit_3',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1, :]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T,4))

print ('\n Average accuracy averaged over different runs: \n %s.' % np.mean(np.round(perUserAcc.T,4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_2.0_30_10u_20b_20_5_0.05_avg_roundNum_0_globalIters_800_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_2.0_30_10u_20b_20_5_0.05_avg_roundNum_1_globalIters_800_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_2.0_30_10u_20b_20_5_0.05_avg_roundNum_2_globalIters_800_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_2.0_30_10u_20b_20_5_0.05_avg_roundNum_3_globalIters_800_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_pFedMe_p_0.01_2.0_30_10u_20b_20_5_0.05_avg_roundNum_4_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7756242360747337, 0.7815610267155579, 0.7778941854374017, 0.7646237122402654, 0.7726558407543216]
#
#  Average accuracy across all the different runs : 0.774472.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9416]
#  [0.7922]
#  [0.6437]
#  [0.7249]
#  [0.7996]
#  [0.7745]
#  [0.8834]
#  [0.8401]
#  [0.6688]
#  [0.7377]].
#
#  Average accuracy averaged over different runs:
#  0.7806500000000001.
