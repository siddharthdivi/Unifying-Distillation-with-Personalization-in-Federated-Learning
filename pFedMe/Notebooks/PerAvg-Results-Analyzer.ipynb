# %%
import numpy as np
import h5py

# %%
# Helper function to help read the h5 files.
def simple_read_data(fileName):
    print(fileName)
    hf = h5py.File('{}.h5'.format(fileName), 'r')
    
    # We'll return a dictionary object. 
    results = {}
    
    results['rs_glob_acc'] = np.array(hf.get('rs_glob_acc')[:])
    results['rs_train_acc'] = np.array(hf.get('rs_train_acc')[:])
    results['rs_train_loss'] = np.array(hf.get('rs_train_loss')[:])
    
    # 3D array: Read as [number of times, number of epochs, number of users].
    results['perUserAccs'] = np.array(hf.get('perUserAccs'))
    
    return results

# %% [markdown]
# ### Datasplit-1

# %%
# Define the global directory path.
directoryPath = '/home/adgdri/pFedMe/results/'

# %% [markdown]
# ### DS-3 latest try

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7242884581805483]
#
#  Average accuracy across all the different runs : 0.724288.
#
#  Average per user accuracy averaged over different runs:
#  [[0.8828]
#  [0.7005]
#  [0.6374]
#  [0.7991]
#  [0.7569]
#  [0.6602]
#  [0.6534]
#  [0.7468]
#  [0.6244]
#  [0.7666]].
#
#  Average per user across all different runs:
#  0.72281.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)b


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7372097083988126]
#
#  Average accuracy across all the different runs : 0.737210.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9202]
#  [0.7184]
#  [0.6374]
#  [0.7511]
#  [0.7661]
#  [0.6964]
#  [0.8285]
#  [0.7179]
#  [0.539 ]
#  [0.7625]].
#
#  Average per user across all different runs:
#  0.7337499999999999.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7073511437052558]
#
#  Average accuracy across all the different runs : 0.707351.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9352]
#  [0.7683]
#  [0.6639]
#  [0.5502]
#  [0.7385]
#  [0.6096]
#  [0.6462]
#  [0.7107]
#  [0.5537]
#  [0.7454]].
#
#  Average per user across all different runs:
#  0.6921700000000001.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7043827483848437]
#
#  Average accuracy across all the different runs : 0.704383.
#
#  Average per user accuracy averaged over different runs:
#  [[0.8728]
#  [0.7291]
#  [0.6308]
#  [0.5895]
#  [0.7403]
#  [0.7494]
#  [0.6949]
#  [0.8047]
#  [0.4951]
#  [0.6953]].
#
#  Average per user across all different runs:
#  0.7001900000000001.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6621267679413305]
#
#  Average accuracy across all the different runs : 0.662127.
#
#  Average per user accuracy averaged over different runs:
#  [[0.803 ]
#  [0.6845]
#  [0.5613]
#  [0.6594]
#  [0.7293]
#  [0.6988]
#  [0.6823]
#  [0.7378]
#  [0.4878]
#  [0.6342]].
#
#  Average per user across all different runs:
#  0.66784.

# %% [markdown]
# ### DS-1 try

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5077]
#
#  Average accuracy across all the different runs : 0.507700.
#
#  Average per user accuracy averaged over different runs:
#  [[0.279]
#  [0.684]
#  [0.476]
#  [0.536]
#  [0.557]
#  [0.505]
#  [0.415]
#  [0.544]
#  [0.593]
#  [0.488]].
#
#  Average per user across all different runs:
#  0.5077.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.441]
#
#  Average accuracy across all the different runs : 0.441000.
#
#  Average per user accuracy averaged over different runs:
#  [[0.502]
#  [0.721]
#  [0.414]
#  [0.256]
#  [0.554]
#  [0.503]
#  [0.276]
#  [0.338]
#  [0.347]
#  [0.499]].
#
#  Average per user across all different runs:
#  0.441.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5613]
#
#  Average accuracy across all the different runs : 0.561300.
#
#  Average per user accuracy averaged over different runs:
#  [[0.509]
#  [0.548]
#  [0.498]
#  [0.896]
#  [0.481]
#  [0.631]
#  [0.462]
#  [0.591]
#  [0.336]
#  [0.661]].
#
#  Average per user across all different runs:
#  0.5612999999999999.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6459]
#
#  Average accuracy across all the different runs : 0.645900.
#
#  Average per user accuracy averaged over different runs:
#  [[0.568]
#  [0.734]
#  [0.521]
#  [0.796]
#  [0.544]
#  [0.637]
#  [0.622]
#  [0.753]
#  [0.547]
#  [0.737]].
#
#  Average per user across all different runs:
#  0.6459.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7304]
#
#  Average accuracy across all the different runs : 0.730400.
#
#  Average per user accuracy averaged over different runs:
#  [[0.708]
#  [0.813]
#  [0.574]
#  [0.887]
#  [0.652]
#  [0.728]
#  [0.647]
#  [0.784]
#  [0.761]
#  [0.75 ]].
#
#  Average per user across all different runs:
#  0.7303999999999999.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5786264120763771]
#
#  Average accuracy across all the different runs : 0.578626.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6068]
#  [0.5599]
#  [0.5717]
#  [0.6382]
#  [0.559 ]
#  [0.6015]
#  [0.5444]
#  [0.5831]
#  [0.5485]
#  [0.6021]].
#
#  Average per user across all different runs:
#  0.58152.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5665300409877037]
#
#  Average accuracy across all the different runs : 0.566530.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5854]
#  [0.568 ]
#  [0.5707]
#  [0.6224]
#  [0.5309]
#  [0.6035]
#  [0.5309]
#  [0.5558]
#  [0.5515]
#  [0.569 ]].
#
#  Average per user across all different runs:
#  0.5688099999999999.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5591322603219034]
#
#  Average accuracy across all the different runs : 0.559132.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5249]
#  [0.5747]
#  [0.5602]
#  [0.6319]
#  [0.4934]
#  [0.5968]
#  [0.5451]
#  [0.5727]
#  [0.5644]
#  [0.569 ]].
#
#  Average per user across all different runs:
#  0.5633100000000001.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5836249125262422]
#
#  Average accuracy across all the different runs : 0.583625.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6283]
#  [0.5559]
#  [0.5895]
#  [0.6319]
#  [0.5723]
#  [0.6068]
#  [0.5257]
#  [0.5649]
#  [0.5535]
#  [0.6379]].
#
#  Average per user across all different runs:
#  0.58667.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5681295611316605]
#
#  Average accuracy across all the different runs : 0.568130.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5941]
#  [0.5518]
#  [0.5686]
#  [0.6177]
#  [0.5278]
#  [0.6115]
#  [0.5295]
#  [0.5545]
#  [0.5455]
#  [0.6021]].
#
#  Average per user across all different runs:
#  0.57031.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.546336099170249]
#
#  Average accuracy across all the different runs : 0.546336.
#
#  Average per user accuracy averaged over different runs:
#  [[0.519 ]
#  [0.5505]
#  [0.5215]
#  [0.5893]
#  [0.5418]
#  [0.5934]
#  [0.5496]
#  [0.5623]
#  [0.4812]
#  [0.5544]].
#
#  Average per user across all different runs:
#  0.5463.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.552034389683095]
#
#  Average accuracy across all the different runs : 0.552034.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5883]
#  [0.5532]
#  [0.5791]
#  [0.5766]
#  [0.5129]
#  [0.5378]
#  [0.4952]
#  [0.539 ]
#  [0.5901]
#  [0.6048]].
#
#  Average per user across all different runs:
#  0.5577.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5455363390982705]
#
#  Average accuracy across all the different runs : 0.545536.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5961]
#  [0.5626]
#  [0.5497]
#  [0.5719]
#  [0.4019]
#  [0.6075]
#  [0.4623]
#  [0.5961]
#  [0.5782]
#  [0.6061]].
#
#  Average per user across all different runs:
#  0.55324.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5035489353194041]
#
#  Average accuracy across all the different runs : 0.503549.
#
#  Average per user accuracy averaged over different runs:
#  [[0.3844]
#  [0.5639]
#  [0.5309]
#  [0.4897]
#  [0.3237]
#  [0.5526]
#  [0.5384]
#  [0.5416]
#  [0.5792]
#  [0.5889]].
#
#  Average per user across all different runs:
#  0.5093300000000001.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4982505248425472]
#
#  Average accuracy across all the different runs : 0.498251.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6049]
#  [0.4872]
#  [0.512 ]
#  [0.5671]
#  [0.3667]
#  [0.5231]
#  [0.4534]
#  [0.4532]
#  [0.505 ]
#  [0.5796]].
#
#  Average per user across all different runs:
#  0.50522.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4646606018194542]
#
#  Average accuracy across all the different runs : 0.464661.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5746]
#  [0.4293]
#  [0.5089]
#  [0.5292]
#  [0.3526]
#  [0.4514]
#  [0.3878]
#  [0.4701]
#  [0.4891]
#  [0.5544]].
#
#  Average per user across all different runs:
#  0.47474.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4341697490752774]
#
#  Average accuracy across all the different runs : 0.434170.
#
#  Average per user accuracy averaged over different runs:
#  [[0.3571]
#  [0.5505]
#  [0.5131]
#  [0.4929]
#  [0.2549]
#  [0.3798]
#  [0.4437]
#  [0.4831]
#  [0.504 ]
#  [0.5265]].
#
#  Average per user across all different runs:
#  0.45056.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4745576327101869]
#
#  Average accuracy across all the different runs : 0.474558.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5668]
#  [0.3943]
#  [0.5246]
#  [0.5292]
#  [0.3284]
#  [0.503 ]
#  [0.3855]
#  [0.4805]
#  [0.5337]
#  [0.5836]].
#
#  Average per user across all different runs:
#  0.48295999999999994.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.45156453064080776]
#
#  Average accuracy across all the different runs : 0.451565.
#
#  Average per user accuracy averaged over different runs:
#  [[0.601 ]
#  [0.4468]
#  [0.5518]
#  [0.5308]
#  [0.3026]
#  [0.3771]
#  [0.3624]
#  [0.4922]
#  [0.4752]
#  [0.5451]].
#
#  Average per user across all different runs:
#  0.46849999999999997.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4495651304608617]
#
#  Average accuracy across all the different runs : 0.449565.
#
#  Average per user accuracy averaged over different runs:
#  [[0.561 ]
#  [0.3917]
#  [0.5361]
#  [0.5782]
#  [0.2541]
#  [0.4983]
#  [0.3885]
#  [0.4195]
#  [0.4307]
#  [0.5371]].
#
#  Average per user across all different runs:
#  0.45952000000000004.

# %% [markdown]
# ### Datasplit-1

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4243]
#
#  Average accuracy across all the different runs : 0.424300.
#
#  Average per user accuracy averaged over different runs:
#  [[0.462]
#  [0.413]
#  [0.494]
#  [0.254]
#  [0.253]
#  [0.527]
#  [0.498]
#  [0.541]
#  [0.263]
#  [0.538]].
#
#  Average per user across all different runs:
#  0.4243.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4006]
#
#  Average accuracy across all the different runs : 0.400600.
#
#  Average per user accuracy averaged over different runs:
#  [[0.386]
#  [0.33 ]
#  [0.492]
#  [0.254]
#  [0.26 ]
#  [0.38 ]
#  [0.45 ]
#  [0.504]
#  [0.263]
#  [0.687]].
#
#  Average per user across all different runs:
#  0.4006.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.483]
#
#  Average accuracy across all the different runs : 0.483000.
#
#  Average per user accuracy averaged over different runs:
#  [[0.509]
#  [0.447]
#  [0.494]
#  [0.389]
#  [0.478]
#  [0.52 ]
#  [0.483]
#  [0.603]
#  [0.268]
#  [0.639]].
#
#  Average per user across all different runs:
#  0.483.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_0_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_0_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4289]
#
#  Average accuracy across all the different runs : 0.428900.
#
#  Average per user accuracy averaged over different runs:
#  [[0.502]
#  [0.419]
#  [0.378]
#  [0.254]
#  [0.419]
#  [0.415]
#  [0.488]
#  [0.637]
#  [0.264]
#  [0.513]].
#
#  Average per user across all different runs:
#  0.42889999999999995.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_0_roundNum_0_globalIters_1000_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_0_roundNum_0_globalIters_1000_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4016]
#
#  Average accuracy across all the different runs : 0.401600.
#
#  Average per user accuracy averaged over different runs:
#  [[0.504]
#  [0.331]
#  [0.412]
#  [0.254]
#  [0.482]
#  [0.311]
#  [0.484]
#  [0.465]
#  [0.261]
#  [0.512]].
#
#  Average per user across all different runs:
#  0.4016.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_0_roundNum_0_globalIters_1200_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_0_roundNum_0_globalIters_1200_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4132]
#
#  Average accuracy across all the different runs : 0.413200.
#
#  Average per user accuracy averaged over different runs:
#  [[0.498]
#  [0.381]
#  [0.321]
#  [0.254]
#  [0.542]
#  [0.378]
#  [0.466]
#  [0.518]
#  [0.262]
#  [0.512]].
#
#  Average per user across all different runs:
#  0.41319999999999996.

# %%
# Set params for DS-1 of CIFAR-10 for PerFed-Avg.

fileNames = [
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5355]
#
#  Average accuracy across all the different runs : 0.535500.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5  ]
#  [0.558]
#  [0.424]
#  [0.276]
#  [0.491]
#  [0.629]
#  [0.527]
#  [0.592]
#  [0.57 ]
#  [0.788]].
#
#  Average per user across all different runs:
#  0.5355000000000001.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4398]
#
#  Average accuracy across all the different runs : 0.439800.
#
#  Average per user accuracy averaged over different runs:
#  [[0.477]
#  [0.405]
#  [0.421]
#  [0.254]
#  [0.305]
#  [0.542]
#  [0.379]
#  [0.612]
#  [0.262]
#  [0.741]].
#
#  Average per user across all different runs:
#  0.43979999999999997.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.3995]
#
#  Average accuracy across all the different runs : 0.399500.
#
#  Average per user accuracy averaged over different runs:
#  [[0.379]
#  [0.411]
#  [0.435]
#  [0.253]
#  [0.243]
#  [0.508]
#  [0.319]
#  [0.658]
#  [0.273]
#  [0.516]].
#
#  Average per user across all different runs:
#  0.3995000000000001.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4057]
#
#  Average accuracy across all the different runs : 0.405700.
#
#  Average per user accuracy averaged over different runs:
#  [[0.506]
#  [0.325]
#  [0.48 ]
#  [0.257]
#  [0.481]
#  [0.322]
#  [0.538]
#  [0.296]
#  [0.353]
#  [0.499]].
#
#  Average per user across all different runs:
#  0.40569999999999995.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.3663]
#
#  Average accuracy across all the different runs : 0.366300.
#
#  Average per user accuracy averaged over different runs:
#  [[0.502]
#  [0.312]
#  [0.488]
#  [0.254]
#  [0.338]
#  [0.258]
#  [0.437]
#  [0.273]
#  [0.289]
#  [0.512]].
#
#  Average per user across all different runs:
#  0.3663.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.3746]
#
#  Average accuracy across all the different runs : 0.374600.
#
#  Average per user accuracy averaged over different runs:
#  [[0.502]
#  [0.301]
#  [0.488]
#  [0.254]
#  [0.386]
#  [0.281]
#  [0.461]
#  [0.279]
#  [0.282]
#  [0.512]].
#
#  Average per user across all different runs:
#  0.3746.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.4709]
#
#  Average accuracy across all the different runs : 0.470900.
#
#  Average per user accuracy averaged over different runs:
#  [[0.483]
#  [0.392]
#  [0.293]
#  [0.292]
#  [0.249]
#  [0.532]
#  [0.491]
#  [0.694]
#  [0.5  ]
#  [0.783]].
#
#  Average per user across all different runs:
#  0.47090000000000004.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.3345]
#
#  Average accuracy across all the different runs : 0.334500.
#
#  Average per user accuracy averaged over different runs:
#  [[0.25 ]
#  [0.29 ]
#  [0.488]
#  [0.254]
#  [0.303]
#  [0.273]
#  [0.468]
#  [0.268]
#  [0.263]
#  [0.488]].
#
#  Average per user across all different runs:
#  0.3345.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.3423]
#
#  Average accuracy across all the different runs : 0.342300.
#
#  Average per user accuracy averaged over different runs:
#  [[0.35 ]
#  [0.257]
#  [0.488]
#  [0.254]
#  [0.317]
#  [0.293]
#  [0.455]
#  [0.258]
#  [0.263]
#  [0.488]].
#
#  Average per user across all different runs:
#  0.34229999999999994.

# %% [markdown]
# ## Datasplit - 2

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_1_globalIters_800_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_2_globalIters_800_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_3_globalIters_800_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_4_globalIters_800_dataSplit_2',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_1_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_2_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_3_globalIters_800_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_4_globalIters_800_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5807257822653205, 0.5977206837948615, 0.5789842031593682, 0.5450364890532841, 0.5604318704388683]
#
#  Average accuracy across all the different runs : 0.572580.
#
#  Average per user accuracy averaged over different runs:
#  [[0.5818]
#  [0.5609]
#  [0.5719]
#  [0.5883]
#  [0.5935]
#  [0.5927]
#  [0.5768]
#  [0.5802]
#  [0.5575]
#  [0.5533]].
#
#  Average per user across all different runs:
#  0.57569.

# %% [markdown]
# ### Datasplit-3

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7337174786100925]
#
#  Average accuracy across all the different runs : 0.733717.
#
#  Average per user accuracy averaged over different runs:
#  [[0.798 ]
#  [0.7718]
#  [0.4354]
#  [0.7249]
#  [0.8029]
#  [0.7205]
#  [0.8628]
#  [0.8463]
#  [0.6024]
#  [0.7495]].
#
#  Average per user across all different runs:
#  0.73145.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6593329841103545]
#
#  Average accuracy across all the different runs : 0.659333.
#
#  Average per user accuracy averaged over different runs:
#  [[0.7606]
#  [0.7718]
#  [0.3808]
#  [0.5895]
#  [0.8085]
#  [0.7229]
#  [0.8791]
#  [0.7812]
#  [0.5268]
#  [0.5484]].
#
#  Average per user across all different runs:
#  0.67696.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.01_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6841278156102671]
#
#  Average accuracy across all the different runs : 0.684128.
#
#  Average per user accuracy averaged over different runs:
#  [[0.8529]
#  [0.7504]
#  [0.3626]
#  [0.6812]
#  [0.7864]
#  [0.6964]
#  [0.8791]
#  [0.7758]
#  [0.3268]
#  [0.696 ]].
#
#  Average per user across all different runs:
#  0.68076.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7220185088178802]
#
#  Average accuracy across all the different runs : 0.722019.
#
#  Average per user accuracy averaged over different runs:
#  [[0.8204]
#  [0.7897]
#  [0.5381]
#  [0.7948]
#  [0.768 ]
#  [0.7566]
#  [0.8791]
#  [0.8463]
#  [0.4902]
#  [0.6651]].
#
#  Average per user across all different runs:
#  0.7348299999999999.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7429718875502008]
#
#  Average accuracy across all the different runs : 0.742972.
#
#  Average per user accuracy averaged over different runs:
#  [[0.8379]
#  [0.7843]
#  [0.4404]
#  [0.8472]
#  [0.768 ]
#  [0.7928]
#  [0.8881]
#  [0.821 ]
#  [0.522 ]
#  [0.7639]].
#
#  Average per user across all different runs:
#  0.74656.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0075_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7241138466911122]
#
#  Average accuracy across all the different runs : 0.724114.
#
#  Average per user accuracy averaged over different runs:
#  [[0.788 ]
#  [0.7629]
#  [0.4073]
#  [0.8603]
#  [0.7532]
#  [0.7494]
#  [0.852 ]
#  [0.8626]
#  [0.4171]
#  [0.7687]].
#
#  Average per user across all different runs:
#  0.72215.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7345905360572725]
#
#  Average accuracy across all the different runs : 0.734591.
#
#  Average per user accuracy averaged over different runs:
#  [[0.8454]
#  [0.7843]
#  [0.5911]
#  [0.7773]
#  [0.7882]
#  [0.8024]
#  [0.861 ]
#  [0.8571]
#  [0.4561]
#  [0.6822]].
#
#  Average per user across all different runs:
#  0.74451.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7153832722193121]
#
#  Average accuracy across all the different runs : 0.715383.
#
#  Average per user accuracy averaged over different runs:
#  [[0.8429]
#  [0.7683]
#  [0.5546]
#  [0.786 ]
#  [0.7845]
#  [0.8096]
#  [0.7996]
#  [0.8553]
#  [0.3585]
#  [0.6781]].
#
#  Average per user across all different runs:
#  0.72374.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7239392352016762]
#
#  Average accuracy across all the different runs : 0.723939.
#
#  Average per user accuracy averaged over different runs:
#  [[0.8454]
#  [0.7683]
#  [0.5248]
#  [0.7467]
#  [0.7974]
#  [0.7783]
#  [0.7978]
#  [0.8571]
#  [0.4488]
#  [0.7083]].
#
#  Average per user across all different runs:
#  0.7272900000000001.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7777195739479658]
#
#  Average accuracy across all the different runs : 0.777720.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9327]
#  [0.7914]
#  [0.6507]
#  [0.786 ]
#  [0.7974]
#  [0.7904]
#  [0.8863]
#  [0.8336]
#  [0.6439]
#  [0.7454]].
#
#  Average per user across all different runs:
#  0.7857800000000001.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7798149118211979]
#
#  Average accuracy across all the different runs : 0.779815.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9377]
#  [0.7736]
#  [0.6656]
#  [0.8253]
#  [0.7974]
#  [0.7807]
#  [0.8574]
#  [0.8336]
#  [0.6463]
#  [0.7598]].
#
#  Average per user across all different runs:
#  0.78774.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1200_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7562423607473372]
#
#  Average accuracy across all the different runs : 0.756242.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9302]
#  [0.7683]
#  [0.6474]
#  [0.8297]
#  [0.7993]
#  [0.7807]
#  [0.7942]
#  [0.8192]
#  [0.5756]
#  [0.7268]].
#
#  Average per user across all different runs:
#  0.7671399999999999.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7724812292648856]
#
#  Average accuracy across all the different runs : 0.772481.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9302]
#  [0.7718]
#  [0.6192]
#  [0.7991]
#  [0.7974]
#  [0.7518]
#  [0.8881]
#  [0.8517]
#  [0.6098]
#  [0.757 ]].
#
#  Average per user across all different runs:
#  0.7776099999999999.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7670682730923695]
#
#  Average accuracy across all the different runs : 0.767068.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9177]
#  [0.7718]
#  [0.6192]
#  [0.8079]
#  [0.7956]
#  [0.6916]
#  [0.87  ]
#  [0.8427]
#  [0.5756]
#  [0.7756]].
#
#  Average per user across all different runs:
#  0.76677.

# %% [markdown]
# ### Datasplit-1 check

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_1_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_2_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_3_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_4_globalIters_800_dataSplit_1',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_1_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_2_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_3_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.005_15_10u_128b_20_avg_roundNum_4_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5355, 0.3668, 0.3986, 0.3634, 0.367]
#
#  Average accuracy across all the different runs : 0.406260.
#
#  Average per user accuracy averaged over different runs:
#  [[0.3826]
#  [0.4006]
#  [0.3766]
#  [0.4466]
#  [0.3618]
#  [0.453 ]
#  [0.38  ]
#  [0.3736]
#  [0.401 ]
#  [0.4868]].
#
#  Average per user across all different runs:
#  0.40625999999999995.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_150_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_150_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_150_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_150_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_150_dataSplit_1',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_150_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_150_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_150_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_150_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_150_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.689, 0.6266, 0.6882, 0.5923, 0.5987]
#
#  Average accuracy across all the different runs : 0.638960.
#
#  Average per user accuracy averaged over different runs:
#  [[0.7062]
#  [0.5842]
#  [0.6122]
#  [0.6324]
#  [0.6678]
#  [0.5754]
#  [0.5394]
#  [0.6066]
#  [0.698 ]
#  [0.7674]].
#
#  Average per user across all different runs:
#  0.63896.

# %% [markdown]
# #### Num Epochs: 25

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_25_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_25_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_25_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_25_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_25_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_25_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_25_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_25_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_25_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_25_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5912, 0.5188, 0.5517, 0.5264, 0.5058]
#
#  Average accuracy across all the different runs : 0.538780.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6184]
#  [0.4686]
#  [0.56  ]
#  [0.5484]
#  [0.5536]
#  [0.4532]
#  [0.4386]
#  [0.532 ]
#  [0.5806]
#  [0.6344]].

# %% [markdown]
# #### Num Epochs: 50

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_50_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_50_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_50_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_50_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_50_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_50_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_50_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_50_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_50_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_50_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6165, 0.5629, 0.6347, 0.5441, 0.5289]
#
#  Average accuracy across all the different runs : 0.577420.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6488]
#  [0.528 ]
#  [0.5678]
#  [0.5792]
#  [0.6006]
#  [0.5106]
#  [0.49  ]
#  [0.5374]
#  [0.6312]
#  [0.6806]].

# %% [markdown]
# #### Num Epochs: 100

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_100_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_100_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_100_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_100_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_100_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_100_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_100_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_100_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_100_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_100_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6697, 0.6182, 0.6809, 0.5919, 0.5728]
#
#  Average accuracy across all the different runs : 0.626700.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6898]
#  [0.5632]
#  [0.6088]
#  [0.6202]
#  [0.6438]
#  [0.5828]
#  [0.5442]
#  [0.5898]
#  [0.6782]
#  [0.7462]].

# %% [markdown]
# #### Num Epochs: 150

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_150_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_150_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_150_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_150_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_150_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_150_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_150_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_150_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_150_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_150_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.689, 0.6266, 0.6882, 0.5923, 0.5987]
#
#  Average accuracy across all the different runs : 0.638960.
#
#  Average per user accuracy averaged over different runs:
#  [[0.7062]
#  [0.5842]
#  [0.6122]
#  [0.6324]
#  [0.6678]
#  [0.5754]
#  [0.5394]
#  [0.6066]
#  [0.698 ]
#  [0.7674]].

# %% [markdown]
# #### Num Epochs: 200

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_200_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_200_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_200_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_200_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_200_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_200_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_200_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_200_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_200_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_200_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6915, 0.6337, 0.6841, 0.5857, 0.5921]
#
#  Average accuracy across all the different runs : 0.637420.
#
#  Average per user accuracy averaged over different runs:
#  [[0.698 ]
#  [0.5706]
#  [0.6298]
#  [0.626 ]
#  [0.6408]
#  [0.5724]
#  [0.556 ]
#  [0.6168]
#  [0.6968]
#  [0.767 ]].

# %% [markdown]
# #### Num Epochs: 300

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_300_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_300_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_300_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_300_dataSplit_1',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_300_dataSplit_1'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_300_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_300_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_300_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_300_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_300_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.6735, 0.6184, 0.6631, 0.5735, 0.5752]
#
#  Average accuracy across all the different runs : 0.620740.
#
#  Average per user accuracy averaged over different runs:
#  [[0.692 ]
#  [0.568 ]
#  [0.6148]
#  [0.6132]
#  [0.6214]
#  [0.5458]
#  [0.5274]
#  [0.5894]
#  [0.6812]
#  [0.7542]].

# %% [markdown]
# ### Datasplit-2

# %% [markdown]
# #### Num Epochs: 25

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_25_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_25_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_25_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_25_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_25_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_25_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_25_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.32426550598476606, 0.26332100369889033, 0.23183045086474058, 0.22770891643342664, 0.29648140743702517]
#
#  Average accuracy across all the different runs : 0.268721.
#
#  Average per user accuracy averaged over different runs:
#  [[0.25283096]
#  [0.27499199]
#  [0.25548378]
#  [0.23076901]
#  [0.27350091]
#  [0.28974282]
#  [0.22819665]
#  [0.27896417]
#  [0.32766968]
#  [0.30952396]].

# %% [markdown]
# #### Num Epochs: 50

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_50_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_50_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_50_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_50_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_50_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_50_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_50_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.32752992383025026, 0.23602919124262722, 0.23842847145856244, 0.24000399840063974, 0.2887844862055178]
#
#  Average accuracy across all the different runs : 0.266155.
#
#  Average per user accuracy averaged over different runs:
#  [[0.27545896]
#  [0.27418982]
#  [0.25756058]
#  [0.21409767]
#  [0.28222709]
#  [0.27661572]
#  [0.23368662]
#  [0.2537826 ]
#  [0.32213575]
#  [0.31222392]].

# %% [markdown]
# #### Num Epochs: 100

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_100_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_100_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_100_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_100_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_100_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_100_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_100_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_100_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_100_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_100_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.31991294885745375, 0.2689193242027392, 0.23642907127861643, 0.23920431827269092, 0.2966813274690124]
#
#  Average accuracy across all the different runs : 0.272229.
#
#  Average per user accuracy averaged over different runs:
#  [[0.27442922]
#  [0.29322539]
#  [0.256024  ]
#  [0.24208991]
#  [0.27425758]
#  [0.2769086 ]
#  [0.24671786]
#  [0.28233375]
#  [0.3302295 ]
#  [0.2998575 ]].

# %% [markdown]
# #### Num Epochs: 200

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_200_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_200_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_200_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_200_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_200_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_200_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_200_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.36235038084874865, 0.2654203738878336, 0.2349295211436569, 0.21961215513794483, 0.2853858456617353]
#
#  Average accuracy across all the different runs : 0.273540.
#
#  Average per user accuracy averaged over different runs:
#  [[0.25836585]
#  [0.29286585]
#  [0.27036847]
#  [0.2291682 ]
#  [0.27638764]
#  [0.27170457]
#  [0.25229956]
#  [0.30268007]
#  [0.32607243]
#  [0.31240729]].

# %% [markdown]
# #### Num Epochs: 300

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_300_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_300_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_300_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_300_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_300_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_300_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_300_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_300_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_300_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_300_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.3939064200217628, 0.25452364290712787, 0.22723183045086473, 0.23700519792083166, 0.290483806477409]
#
#  Average accuracy across all the different runs : 0.280630.
#
#  Average per user accuracy averaged over different runs:
#  [[0.28  ]
#  [0.3162]
#  [0.2886]
#  [0.2374]
#  [0.2621]
#  [0.288 ]
#  [0.2678]
#  [0.2894]
#  [0.3221]
#  [0.3107]].

# %% [markdown]
# #### Num Epochs: 400

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_400_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_400_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_400_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_400_dataSplit_2',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_400_dataSplit_2'
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_400_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_400_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_400_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_400_dataSplit_2
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_400_dataSplit_2
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.37323177366702937, 0.26352094371688495, 0.21883434969509147, 0.2272091163534586, 0.2929828068772491]
#
#  Average accuracy across all the different runs : 0.275156.
#
#  Average per user accuracy averaged over different runs:
#  [[0.28135143]
#  [0.31351966]
#  [0.28432588]
#  [0.23428243]
#  [0.25984846]
#  [0.27714805]
#  [0.26973722]
#  [0.27749068]
#  [0.31578003]
#  [0.30746334]].

# %% [markdown]
# ### Datasplit-3

# %% [markdown]
# #### Num Epochs: 25

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_25_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_25_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_25_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_25_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_25_dataSplit_3',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_25_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_25_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_25_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_25_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_25_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5262790291601187, 0.5213899074559106, 0.5247075257551946, 0.5302950934171469, 0.5185961236249346]
#
#  Average accuracy across all the different runs : 0.524254.
#
#  Average per user accuracy averaged over different runs:
#  [[0.76458853]
#  [0.54616756]
#  [0.47450331]
#  [0.51266376]
#  [0.7281768 ]
#  [0.55566265]
#  [0.48158845]
#  [0.54177215]
#  [0.36439024]
#  [0.44172958]].

# %% [markdown]
# #### Num Epochs: 50

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_50_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_50_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_50_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_50_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_50_dataSplit_3',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_50_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_50_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_50_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_50_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_50_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5264536406495547, 0.5212152959664746, 0.5229614108608347, 0.5236598568185786, 0.5308189278854548]
#
#  Average accuracy across all the different runs : 0.525022.
#
#  Average per user accuracy averaged over different runs:
#  [[0.7646]
#  [0.5462]
#  [0.4798]
#  [0.5127]
#  [0.7282]
#  [0.5557]
#  [0.4816]
#  [0.5418]
#  [0.3337]
#  [0.4512]].

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_100_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_100_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_100_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_100_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_100_dataSplit_3',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][-1]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % perUserAcc.T)
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_0_globalIters_100_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_1_globalIters_100_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_2_globalIters_100_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_3_globalIters_100_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.001_15_10u_128b_20_0_roundNum_4_globalIters_100_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.5275013095861708, 0.5198184040509866, 0.5201676270298585, 0.5121354985158023, 0.5257551946918108]
#
#  Average accuracy across all the different runs : 0.521076.
#
#  Average per user accuracy averaged over different runs:
#  [[0.76458853]
#  [0.54616756]
#  [0.47980132]
#  [0.51615721]
#  [0.7281768 ]
#  [0.55566265]
#  [0.48158845]
#  [0.54177215]
#  [0.31365854]
#  [0.4407687 ]].

# %% [markdown]
# ### Datasplit-3

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_1_globalIters_1000_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_2_globalIters_1000_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_3_globalIters_1000_dataSplit_3',
    'Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_4_globalIters_1000_dataSplit_3',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_0_globalIters_1000_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_1_globalIters_1000_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_2_globalIters_1000_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_3_globalIters_1000_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.01_0.0025_15_10u_128b_20_avg_roundNum_4_globalIters_1000_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7798149118211979, 0.7745765671381177, 0.7606076479832373, 0.7667190501134975, 0.7604330364938013]
#
#  Average accuracy across all the different runs : 0.768430.
#
#  Average per user accuracy averaged over different runs:
#  [[0.9247]
#  [0.7373]
#  [0.6464]
#  [0.7703]
#  [0.825 ]
#  [0.7793]
#  [0.8913]
#  [0.8373]
#  [0.641 ]
#  [0.7266]].
#
#  Average per user across all different runs:
#  0.7779200000000001.

# %% [markdown]
# ### Datasplit-1

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_800_dataSplit_1',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7304, 0.6293, 0.7196, 0.6333, 0.6337]
#
#  Average accuracy across all the different runs : 0.669260.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6916]
#  [0.6504]
#  [0.6786]
#  [0.6718]
#  [0.6576]
#  [0.6268]
#  [0.5824]
#  [0.6428]
#  [0.7246]
#  [0.766 ]].
#
#  Average per user across all different runs:
#  0.66926.

# %%
# Define the global directory path.
directoryPath = '/home/adgdri/pFedMe/results_oldRuns/'

fileNames = [
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_800_dataSplit_1',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results_oldRuns/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_0_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results_oldRuns/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_1_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results_oldRuns/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_2_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results_oldRuns/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_3_globalIters_800_dataSplit_1
# /home/adgdri/pFedMe/results_oldRuns/Cifar10_PerAvg_p_0.001_0.001_15_10u_128b_20_avg_roundNum_4_globalIters_800_dataSplit_1
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.7304, 0.6293, 0.7196, 0.6333, 0.6337]
#
#  Average accuracy across all the different runs : 0.669260.
#
#  Average per user accuracy averaged over different runs:
#  [[0.6916]
#  [0.6504]
#  [0.6786]
#  [0.6718]
#  [0.6576]
#  [0.6268]
#  [0.5824]
#  [0.6428]
#  [0.7246]
#  [0.766 ]].
#
#  Average per user across all different runs:
#  0.66926.

# %% [markdown]
# ### CIFAR pFedMe paper param check

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_0_globalIters_800_dataSplit_3',
    'Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_1_globalIters_800_dataSplit_3',
    'Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_2_globalIters_800_dataSplit_3',
    'Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_3_globalIters_800_dataSplit_3',
    'Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_4_globalIters_800_dataSplit_3',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
# Out:
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_0_globalIters_800_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_1_globalIters_800_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_2_globalIters_800_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_3_globalIters_800_dataSplit_3
# /home/adgdri/pFedMe/results/Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_4_globalIters_800_dataSplit_3
# ----------------------------------------
#
#  Average accuracies across all the users over different runs : [0.748210232233281, 0.7319713637157325, 0.7613060939409814, 0.7461148943600489, 0.7434957220185088]
#
#  Average accuracy across all the different runs : 0.746220.
#
#  Average per user accuracy averaged over different runs:
#  [[0.8988]
#  [0.7501]
#  [0.645 ]
#  [0.7668]
#  [0.7867]
#  [0.7383]
#  [0.8603]
#  [0.7881]
#  [0.5898]
#  [0.7134]].
#
#  Average per user across all different runs:
#  0.75373.

# %%
fileNames = [
    'Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_0_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_1_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_2_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_3_globalIters_800_dataSplit_1',
    'Cifar10_PerAvg_p_0.02_0.001_15_10u_20b_20_avg_roundNum_4_globalIters_800_dataSplit_1',
]


# Get the number of users.
numUsers = int(fileNames[0].split('u')[0].split('_')[-1])

avgPersAcc = []
perUserAcc = np.zeros((1, numUsers))

for fileName in fileNames:
    ob = simple_read_data(directoryPath + fileName)
    avgPersAcc.append( ob['rs_glob_acc'][-1] )
    # Take the per user accuracy from the last epoch.
    perUserAcc += ob['perUserAccs'][:,-1,:]

# Average out over the different runs.
perUserAcc /= len(fileNames)


print ('----------------------------------------')

print ('\n Average accuracies across all the users over different runs : %s' % avgPersAcc)

print ('\n Average accuracy across all the different runs : %f.' % np.mean(avgPersAcc) )

print ('\n Average per user accuracy averaged over different runs: \n %s.' % np.round(perUserAcc.T, 4))

print ('\n Average per user across all different runs: \n %s.' % np.mean(np.round(perUserAcc.T, 4)) )
